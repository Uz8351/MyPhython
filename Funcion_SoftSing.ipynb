# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/Funcion_SoftSing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Derivada descenso de gradiente
de la función:SoftSing.
SoftSing(x)=x/1+|x|

"""
import numpy as np
import matplotlib.pyplot as plt

def Mi_Funcion(x):
  return x / (1 + np.abs(x))


def Hacer_Derivada(x):
    return np.abs(x) + x
#Crea un array llamado x que contiene 250 puntos igualmente espaciados en el rango desde -20 hasta 20.
x = np.linspace(-20, 20, 250)

# Inicializamos un punto cualquiera, por ejemplo iniciamos x en 18.
Inicio_x = 18
# Establecemos el coeficiente de aprendizaje (learning rate), inicialmente en 0.05
lr = 0.05
# Definimos el punto de partida aplicando derivada y coeficiente de aprendizaje.
Punto_x = Inicio_x - Hacer_Derivada(Inicio_x) * lr
Iniciar_y = Mi_Funcion(Inicio_x)

# Aquí comenzamos a diseñar la gráfica.
plt.plot(x, Mi_Funcion(x))  # Graficamos la función softSign
plt.plot(Inicio_x, Iniciar_y, 'bo')  # Señalamos el punto de inicio

for i in range(1000):
    Punto_x = Punto_x - Hacer_Derivada(Punto_x) * lr
    Iniciar_y = Mi_Funcion(Punto_x)
    plt.plot(Punto_x, Iniciar_y, 'bo')

    # Actualizamos mínimo valor de derivada y punto correspondiente
    if Hacer_Derivada(Punto_x) < Hacer_Derivada(Minimo_Punto_x):
        Minimo_Punto_x = Punto_x

plt.grid(True, which='both', linestyle='-', linewidth=0.5, color='gray')
plt.minorticks_on()

# Ajustamos el espaciado de las minorticks en los ejes x e y
plt.gca().xaxis.set_minor_locator(plt.MultipleLocator(5))
plt.gca().yaxis.set_minor_locator(plt.MultipleLocator(5))
#Imprimimos el .mínimo punto en x
print('\n')
print("*******************************************************************************")
print("Valor mínimo del punto coincidente con la mínima derivada:", Minimo_Punto_x)
print("*******************************************************************************")
print('\n')
plt.show()
# Out:
# *******************************************************************************
# Valor mínimo del punto coincidente con la mínima derivada: 2.831551427790681e-45
# *******************************************************************************
