# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/Untitled175.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
neurotica.py
"""

import numpy as np

# Función ReLU
def relu(x):
    return np.maximum(0, x)

# Derivada de la función ReLU
def relu_derivada(x):
    return np.where(x > 0, 1, 0)

# Datos de entrenamiento
X = np.array([[50, 2],     # Presión sistólica  1: 50, 2 Tomas de tensión.
              [70, 3],     # Presión sistólica  2: 50, 2 Tomas de tensión.
              [90, 5],     # Presión sistólica  3: 50, 2 Tomas de tensión.
              [90, 4],     # Presión sistólica  4: 50, 2 Tomas de tensión.
              [80, 6],     # Presión sistólica  5: 50, 2 Tomas de tensión.
              [80, 6]])    # Presión sistólica  6: 50, 2 Tomas de tensión.

# Valores objetivo (ajustados para que coincida con el número de Tomas)
y = np.array([[0.5], [0.7], [0.9], [0.8], [0.6], [0.85]])

# Pesos de la capa oculta (6 neuronas, 2 entradas) - Inicializados aleatoriamente y divididos por 100
W1 = np.random.randn(2, 6) / 100

# Pesos de la capa de salida (6 neuronas en oculta, 1 neurona en salida) - Inicializados aleatoriamente y divididos por 100
W2 = np.random.randn(6, 1) / 100

# Tasa de aprendizaje
learning_rate = 0.001

# Entrenamiento durante 100 épocas
for epoch in range(100):
    # Propagación hacia adelante
    capa_oculta = np.dot(X, W1)
    capa_oculta_act = relu(capa_oculta)
    salida = np.dot(capa_oculta_act, W2)
    salida_act = relu(salida)

    # Calcular el error
    error = y - salida_act

    # Backpropagation
    d_salida = error * relu_derivada(salida)
    d_W2 = np.dot(capa_oculta_act.T, d_salida) / X.shape[0]
    d_W1 = np.dot(X.T, np.dot(d_salida, W2.T) * relu_derivada(capa_oculta)) / X.shape[0]

    # Actualizar pesos y sesgos
    W2 += learning_rate * d_W2
    W1 += learning_rate * d_W1

    # Mostrar el error en cada época
    mse = np.mean(np.square(error))
    print(f"Época {epoch + 1}/{100}, Epoca, iteración completa-Error---->: {mse}")

# Imprimir la salida después de 100 épocas de entrenamiento
print("Salida después de entrenamiento:")
print(salida_act)
# Out:
# Época 1/100, Epoca, iteración completa-Error---->: 0.5438280158809059
# Época 2/100, Epoca, iteración completa-Error---->: 0.543319007113337
# Época 3/100, Epoca, iteración completa-Error---->: 0.5427864493775849
# Época 4/100, Epoca, iteración completa-Error---->: 0.5422236379800751
# Época 5/100, Epoca, iteración completa-Error---->: 0.5416235543555307
# Época 6/100, Epoca, iteración completa-Error---->: 0.5409787837266414
# Época 7/100, Epoca, iteración completa-Error---->: 0.5402814303600955
# Época 8/100, Epoca, iteración completa-Error---->: 0.5395230297787552
# Época 9/100, Epoca, iteración completa-Error---->: 0.5386944573781437
# Época 10/100, Epoca, iteración completa-Error---->: 0.5377858330000639
# Época 11/100, Epoca, iteración completa-Error---->: 0.5367864211441006
# Época 12/100, Epoca, iteración completa-Error---->: 0.535684526657035
# Época 13/100, Epoca, iteración completa-Error---->: 0.534467385940212
# Época 14/100, Epoca, iteración completa-Error---->: 0.5331210539665019
# Época 15/100, Epoca, iteración completa-Error---->: 0.5316302877141428
# Época 16/100, Epoca, iteración completa-Error---->: 0.5299784270186003
# Época 17/100, Epoca, iteración completa-Error---->: 0.5281472743314382
# Época 18/100, Epoca, iteración completa-Error---->: 0.5261169754743006
# Época 19/100, Epoca, iteración completa-Error---->: 0.5238659042046866
# Época 20/100, Epoca, iteración completa-Error---->: 0.5213705542866213
# Época 21/100, Epoca, iteración completa-Error---->: 0.5186054438007975
# Época 22/100, Epoca, iteración completa-Error---->: 0.5155430376492801
# Época 23/100, Epoca, iteración completa-Error---->: 0.5121536956174233
# Época 24/100, Epoca, iteración completa-Error---->: 0.5084056549481731
# Época 25/100, Epoca, iteración completa-Error---->: 0.5042650581440493
# Época 26/100, Epoca, iteración completa-Error---->: 0.49969603860031037
# Época 27/100, Epoca, iteración completa-Error---->: 0.49466087861895397
# Época 28/100, Epoca, iteración completa-Error---->: 0.4891202562465631
# Época 29/100, Epoca, iteración completa-Error---->: 0.4830335990569476
# Época 30/100, Epoca, iteración completa-Error---->: 0.47635956423607656
# Época 31/100, Epoca, iteración completa-Error---->: 0.4690566648222383
# Época 32/100, Epoca, iteración completa-Error---->: 0.4610840613286875
# Época 33/100, Epoca, iteración completa-Error---->: 0.45240253576969724
# Época 34/100, Epoca, iteración completa-Error---->: 0.44297566079784434
# Época 35/100, Epoca, iteración completa-Error---->: 0.4327711696793936
# Época 36/100, Epoca, iteración completa-Error---->: 0.4217625226461115
# Época 37/100, Epoca, iteración completa-Error---->: 0.40993065133549894
# Época 38/100, Epoca, iteración completa-Error---->: 0.3972658453695561
# Época 39/100, Epoca, iteración completa-Error---->: 0.3837697238162685
# Época 40/100, Epoca, iteración completa-Error---->: 0.3694572100878926
# Época 41/100, Epoca, iteración completa-Error---->: 0.3543584032615894
# Época 42/100, Epoca, iteración completa-Error---->: 0.33852021424759143
# Época 43/100, Epoca, iteración completa-Error---->: 0.3220076149805693
# Época 44/100, Epoca, iteración completa-Error---->: 0.3049043369571517
# Época 45/100, Epoca, iteración completa-Error---->: 0.28731285648977867
# Época 46/100, Epoca, iteración completa-Error---->: 0.26935352227550124
# Época 47/100, Epoca, iteración completa-Error---->: 0.25116271945171836
# Época 48/100, Epoca, iteración completa-Error---->: 0.23289002422416594
# Época 49/100, Epoca, iteración completa-Error---->: 0.21469438222778434
# Época 50/100, Epoca, iteración completa-Error---->: 0.19673943599913948
# Época 51/100, Epoca, iteración completa-Error---->: 0.17918822242718538
# Época 52/100, Epoca, iteración completa-Error---->: 0.16219754697679545
# Época 53/100, Epoca, iteración completa-Error---->: 0.14591240392512672
# Época 54/100, Epoca, iteración completa-Error---->: 0.1304608384169896
# Época 55/100, Epoca, iteración completa-Error---->: 0.11594962879218473
# Época 56/100, Epoca, iteración completa-Error---->: 0.10246110499565046
# Época 57/100, Epoca, iteración completa-Error---->: 0.0900513173046336
# Época 58/100, Epoca, iteración completa-Error---->: 0.07874964249823362
# Época 59/100, Epoca, iteración completa-Error---->: 0.06855978000688111
# Época 60/100, Epoca, iteración completa-Error---->: 0.059461967643477436
# Época 61/100, Epoca, iteración completa-Error---->: 0.051416151624174865
# Época 62/100, Epoca, iteración completa-Error---->: 0.04436578933383325
# Época 63/100, Epoca, iteración completa-Error---->: 0.0382419489541192
# Época 64/100, Epoca, iteración completa-Error---->: 0.03296739384362817
# Época 65/100, Epoca, iteración completa-Error---->: 0.028460392285283322
# Época 66/100, Epoca, iteración completa-Error---->: 0.024638062971252424
# Época 67/100, Epoca, iteración completa-Error---->: 0.02141914133013441
# Época 68/100, Epoca, iteración completa-Error---->: 0.01872612143258789
# Época 69/100, Epoca, iteración completa-Error---->: 0.016486785823333374
# Época 70/100, Epoca, iteración completa-Error---->: 0.014635177750855878
# Época 71/100, Epoca, iteración completa-Error---->: 0.013112096449306337
# Época 72/100, Epoca, iteración completa-Error---->: 0.011865208099459283
# Época 73/100, Epoca, iteración completa-Error---->: 0.010848865826034004
# Época 74/100, Epoca, iteración completa-Error---->: 0.010023724955104183
# Época 75/100, Epoca, iteración completa-Error---->: 0.009356227939594654
# Época 76/100, Epoca, iteración completa-Error---->: 0.008818019493954424
# Época 77/100, Epoca, iteración completa-Error---->: 0.008385338501445176
# Época 78/100, Epoca, iteración completa-Error---->: 0.008038420432980366
# Época 79/100, Epoca, iteración completa-Error---->: 0.0077609330356018065
# Época 80/100, Epoca, iteración completa-Error---->: 0.00753945916812085
# Época 81/100, Epoca, iteración completa-Error---->: 0.007363033843592067
# Época 82/100, Epoca, iteración completa-Error---->: 0.007222737570809473
# Época 83/100, Epoca, iteración completa-Error---->: 0.007111344674163922
# Época 84/100, Epoca, iteración completa-Error---->: 0.007023023096800927
# Época 85/100, Epoca, iteración completa-Error---->: 0.006953080958371621
# Época 86/100, Epoca, iteración completa-Error---->: 0.0068977545870451545
# Época 87/100, Epoca, iteración completa-Error---->: 0.006854032663807162
# Época 88/100, Epoca, iteración completa-Error---->: 0.00681951133975806
# Época 89/100, Epoca, iteración completa-Error---->: 0.006792275590159086
# Época 90/100, Epoca, iteración completa-Error---->: 0.006770802563342802
# Época 91/100, Epoca, iteración completa-Error---->: 0.006753883207212736
# Época 92/100, Epoca, iteración completa-Error---->: 0.006740558971163089
# Época 93/100, Epoca, iteración completa-Error---->: 0.0067300708628463225
# Época 94/100, Epoca, iteración completa-Error---->: 0.006721818574455211
# Época 95/100, Epoca, iteración completa-Error---->: 0.006715327776828025
# Época 96/100, Epoca, iteración completa-Error---->: 0.0067102240114329395
# Época 97/100, Epoca, iteración completa-Error---->: 0.00670621189285537
# Época 98/100, Epoca, iteración completa-Error---->: 0.006703058572169515
# Época 99/100, Epoca, iteración completa-Error---->: 0.006700580609634448
# Época 100/100, Epoca, iteración completa-Error---->: 0.006698633568774172
# Salida después de entrenamiento:
# [[0.47050332]
#  [0.65845873]
#  [0.84518459]
#  [0.84641415]
#  [0.74936255]
#  [0.74936255]]
