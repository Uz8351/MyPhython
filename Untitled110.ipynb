# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/Untitled110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# Datos de entrenamiento (ejemplo simplificado)
x_train = np.random.rand(1000, 20)  # 1000 ejemplos de 20 características cada uno
y_train = np.random.randint(2, size=1000)  # 1000 etiquetas binarias (0 o 1)

# Definir el modelo (ejemplo simplificado)
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(20,)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# Compilar el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(x_train, y_train, epochs=120, batch_size=32, validation_split=0.2)

# Obtener el historial de entrenamiento
loss = history.history['loss']
accuracy = history.history['accuracy']
val_loss = history.history['val_loss']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(loss) + 1)

# Graficar la pérdida y precisión durante el entrenamiento
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, loss, 'r', label='Pérdida de entrenamiento')
plt.plot(epochs, val_loss, 'b', label='Pérdida de validación')
plt.title('Pérdida durante el entrenamiento y la validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, accuracy, 'r', label='Precisión de entrenamiento')
plt.plot(epochs, val_accuracy, 'b', label='Precisión de validación')
plt.title('Precisión durante el entrenamiento y la validación')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/120
# 25/25 [==============================] - 2s 16ms/step - loss: 0.6931 - accuracy: 0.5175 - val_loss: 0.6974 - val_accuracy: 0.5200
# Epoch 2/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6873 - accuracy: 0.5487 - val_loss: 0.6985 - val_accuracy: 0.5150
# Epoch 3/120
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6869 - accuracy: 0.5475 - val_loss: 0.6963 - val_accuracy: 0.5100
# Epoch 4/120
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6853 - accuracy: 0.5550 - val_loss: 0.7028 - val_accuracy: 0.5050
# Epoch 5/120
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6796 - accuracy: 0.5725 - val_loss: 0.6987 - val_accuracy: 0.5150
# Epoch 6/120
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6815 - accuracy: 0.5788 - val_loss: 0.7022 - val_accuracy: 0.5000
# Epoch 7/120
# ...
