# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/Copia_de_Untitled178.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Función ReLU
def relu(x):
    return np.maximum(0, x)

# Derivada de la función ReLU
def relu_derivada(x):
    return np.where(x > 0, 1, 0)

# Datos de entrenamiento
X = np.array([[50, 2],     # Presión sistólica  1:  2 Tomas de tensión.
              [70, 3],     # Presión sistólica  1:  3 Tomas de tensión.
              [90, 5],     # Presión sistólica  1:  5 Tomas de tensión.
              [90, 4],     # Presión sistólica  1:  4 Tomas de tensión.
              [80, 6],     # Presión sistólica  1:  6 Tomas de tensión.
              [80, 6]])    # Presión sistólica  1:  6 Tomas de tensión.

# Valores objetivo (ajustados para que coincida con el número de Tomas)
y = np.array([[0.5], [0.7], [0.9], [0.8], [0.6], [0.85]])

# Pesos de la capa oculta (6 neuronas, 2 entradas) - Inicializados aleatoriamente y divididos por 100
W1 = np.random.randn(2, 6) / 100

# Pesos de la capa de salida (6 neuronas en oculta, 1 neurona en salida) - Inicializados aleatoriamente y divididos por 100
W2 = np.random.randn(6, 1) / 100

# Tasa de aprendizaje
learning_rate = 0.001

# Entrenamiento durante 1000 épocas
for epoch in range(100):
    # Propagación hacia adelante
    capa_oculta = np.dot(X, W1)
    capa_oculta_act = relu(capa_oculta)
    salida = np.dot(capa_oculta_act, W2)
    salida_act = relu(salida)

    # Calcular el error
    error = y - salida_act

    # Backpropagation
    d_salida = error * relu_derivada(salida)
    d_W2 = np.dot(capa_oculta_act.T, d_salida) / X.shape[0]
    d_W1 = np.dot(X.T, np.dot(d_salida, W2.T) * relu_derivada(capa_oculta)) / X.shape[0]

    # Actualizar pesos y sesgos
    W2 += learning_rate * d_W2
    W1 += learning_rate * d_W1

    # Mostrar el error en cada época
    mse = np.mean(np.square(error))
    print(f"Época {epoch + 1}/{100}, Epoca, iteración completa-Error---->: {mse}")

# Imprimir la salida después de 1000 épocas de entrenamiento
print("Salida después de entrenamiento:")
print(salida_act)
# Out:
# Época 1/100, Epoca, iteración completa-Error---->: 0.5423447478625821
# Época 2/100, Epoca, iteración completa-Error---->: 0.5417913372644931
# Época 3/100, Epoca, iteración completa-Error---->: 0.5411949969792673
# Época 4/100, Epoca, iteración completa-Error---->: 0.5405484241631245
# Época 5/100, Epoca, iteración completa-Error---->: 0.5398437655517038
# Época 6/100, Epoca, iteración completa-Error---->: 0.5390725321396187
# Época 7/100, Epoca, iteración completa-Error---->: 0.5382255096111025
# Época 8/100, Epoca, iteración completa-Error---->: 0.5372926641799995
# Época 9/100, Epoca, iteración completa-Error---->: 0.5362630436297944
# Época 10/100, Epoca, iteración completa-Error---->: 0.5351246735128746
# Época 11/100, Epoca, iteración completa-Error---->: 0.5338644486826458
# Época 12/100, Epoca, iteración completa-Error---->: 0.5324680206037716
# Época 13/100, Epoca, iteración completa-Error---->: 0.5309196812277622
# Época 14/100, Epoca, iteración completa-Error---->: 0.5292022446481289
# Época 15/100, Epoca, iteración completa-Error---->: 0.5272969282776914
# Época 16/100, Epoca, iteración completa-Error---->: 0.5251832359380452
# Época 17/100, Epoca, iteración completa-Error---->: 0.5228388460359984
# Época 18/100, Epoca, iteración completa-Error---->: 0.5202395089420083
# Época 19/100, Epoca, iteración completa-Error---->: 0.517358958797422
# Época 20/100, Epoca, iteración completa-Error---->: 0.5141688462725492
# Época 21/100, Epoca, iteración completa-Error---->: 0.5106387002806221
# Época 22/100, Epoca, iteración completa-Error---->: 0.5067359283158855
# Época 23/100, Epoca, iteración completa-Error---->: 0.5024258669018137
# Época 24/100, Epoca, iteración completa-Error---->: 0.4976718955567647
# Época 25/100, Epoca, iteración completa-Error---->: 0.4924356296237111
# Época 26/100, Epoca, iteración completa-Error---->: 0.4866772091373605
# Época 27/100, Epoca, iteración completa-Error---->: 0.4803557024286936
# Época 28/100, Epoca, iteración completa-Error---->: 0.47342964413857186
# Época 29/100, Epoca, iteración completa-Error---->: 0.4658577273963597
# Época 30/100, Epoca, iteración completa-Error---->: 0.4575996687031802
# Época 31/100, Epoca, iteración completa-Error---->: 0.4486172610531829
# Época 32/100, Epoca, iteración completa-Error---->: 0.438875625484587
# Época 33/100, Epoca, iteración completa-Error---->: 0.42834466301459734
# Época 34/100, Epoca, iteración completa-Error---->: 0.4170006972714189
# Época 35/100, Epoca, iteración completa-Error---->: 0.40482828274107
# Época 36/100, Epoca, iteración completa-Error---->: 0.391822134338289
# Época 37/100, Epoca, iteración completa-Error---->: 0.3779891113924136
# Época 38/100, Epoca, iteración completa-Error---->: 0.36335016415689214
# Época 39/100, Epoca, iteración completa-Error---->: 0.3479421254605597
# Época 40/100, Epoca, iteración completa-Error---->: 0.3318192068863171
# Época 41/100, Epoca, iteración completa-Error---->: 0.3150540415403587
# Época 42/100, Epoca, iteración completa-Error---->: 0.2977381083784369
# Época 43/100, Epoca, iteración completa-Error---->: 0.2799813806887597
# Época 44/100, Epoca, iteración completa-Error---->: 0.2619110676353826
# Época 45/100, Epoca, iteración completa-Error---->: 0.2436693651430022
# Época 46/100, Epoca, iteración completa-Error---->: 0.22541020065404674
# Época 47/100, Epoca, iteración completa-Error---->: 0.20729504170608856
# Época 48/100, Epoca, iteración completa-Error---->: 0.18948793321435986
# Época 49/100, Epoca, iteración completa-Error---->: 0.1721500215496421
# Época 50/100, Epoca, iteración completa-Error---->: 0.15543390142334845
# Época 51/100, Epoca, iteración completa-Error---->: 0.13947817059362078
# Época 52/100, Epoca, iteración completa-Error---->: 0.12440258655393943
# Época 53/100, Epoca, iteración completa-Error---->: 0.11030418313904973
# Época 54/100, Epoca, iteración completa-Error---->: 0.09725462515124324
# Época 55/100, Epoca, iteración completa-Error---->: 0.08529896510774015
# Época 56/100, Epoca, iteración completa-Error---->: 0.0744558337215158
# Época 57/100, Epoca, iteración completa-Error---->: 0.06471896371471648
# Época 58/100, Epoca, iteración completa-Error---->: 0.056059833465711785
# Época 59/100, Epoca, iteración completa-Error---->: 0.04843113710966731
# Época 60/100, Epoca, iteración completa-Error---->: 0.04177074872003233
# Época 61/100, Epoca, iteración completa-Error---->: 0.03600585033391226
# Época 62/100, Epoca, iteración completa-Error---->: 0.031056930570348557
# Época 63/100, Epoca, iteración completa-Error---->: 0.026841421804708998
# Época 64/100, Epoca, iteración completa-Error---->: 0.02327681703136519
# Época 65/100, Epoca, iteración completa-Error---->: 0.020283181225652116
# Época 66/100, Epoca, iteración completa-Error---->: 0.01778503733449096
# Época 67/100, Epoca, iteración completa-Error---->: 0.015712658496828454
# Época 68/100, Epoca, iteración completa-Error---->: 0.014002833573593517
# Época 69/100, Epoca, iteración completa-Error---->: 0.012599193109229167
# Época 70/100, Epoca, iteración completa-Error---->: 0.011452189802258683
# Época 71/100, Epoca, iteración completa-Error---->: 0.010518824655928105
# Época 72/100, Epoca, iteración completa-Error---->: 0.009762200566972216
# Época 73/100, Epoca, iteración completa-Error---->: 0.009150972175347123
# Época 74/100, Epoca, iteración completa-Error---->: 0.008658746693827789
# Época 75/100, Epoca, iteración completa-Error---->: 0.00826347681778898
# Época 76/100, Epoca, iteración completa-Error---->: 0.0079468746949346
# Época 77/100, Epoca, iteración completa-Error---->: 0.007693865806962424
# Época 78/100, Epoca, iteración completa-Error---->: 0.007492093599923581
# Época 79/100, Epoca, iteración completa-Error---->: 0.00733147967515516
# Época 80/100, Epoca, iteración completa-Error---->: 0.007203840062256492
# Época 81/100, Epoca, iteración completa-Error---->: 0.007102555229462876
# Época 82/100, Epoca, iteración completa-Error---->: 0.0070222897329095596
# Época 83/100, Epoca, iteración completa-Error---->: 0.0069587564814108304
# Época 84/100, Epoca, iteración completa-Error---->: 0.006908520257611953
# Época 85/100, Epoca, iteración completa-Error---->: 0.006868835197109609
# Época 86/100, Epoca, iteración completa-Error---->: 0.006837511236592692
# Época 87/100, Epoca, iteración completa-Error---->: 0.006812804991478294
# Época 88/100, Epoca, iteración completa-Error---->: 0.006793331036210785
# Época 89/100, Epoca, iteración completa-Error---->: 0.0067779900847785525
# Época 90/100, Epoca, iteración completa-Error---->: 0.006765911072426853
# Época 91/100, Epoca, iteración completa-Error---->: 0.006756404603073254
# Época 92/100, Epoca, iteración completa-Error---->: 0.006748925641215785
# Época 93/100, Epoca, iteración completa-Error---->: 0.00674304368922849
# Época 94/100, Epoca, iteración completa-Error---->: 0.006738419001999566
# Época 95/100, Epoca, iteración completa-Error---->: 0.006734783654411908
# Época 96/100, Epoca, iteración completa-Error---->: 0.0067319264979578295
# Época 97/100, Epoca, iteración completa-Error---->: 0.006729681226045583
# Época 98/100, Epoca, iteración completa-Error---->: 0.0067279169184985554
# Época 99/100, Epoca, iteración completa-Error---->: 0.006726530559259477
# Época 100/100, Epoca, iteración completa-Error---->: 0.0067254411218166795
# Salida después de entrenamiento:
# [[0.47011725]
#  [0.65810784]
#  [0.84581686]
#  [0.84609842]
#  [0.75139921]
#  [0.75139921]]
