# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/Copia_de_ParaMartes_ParametrosPesoSesgoCostoA_220_SEP_12_23_Rv_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar librerías
import numpy as np
import matplotlib.pyplot as plt

# Generar datos aleatorios para entrada y salida
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Definir los parámetros iniciales del modelo
w = 0 # Peso
b = 0 # Sesgo
alpha = 0.01 # Tasa de aprendizaje
iteraciones = 100 # Número de iteraciones

# Definir la función de costo
def costo(w, b):
    return np.mean((y - (w * X + b)) ** 2)#f(x)=m*X+b

# Definir la función de gradiente
def gradiente(w, b):
    dw = -2 * np.mean(X * (y - (w * X + b))) # Derivada parcial respecto a w
    db = -2 * np.mean(y - (w * X + b)) # Derivada parcial respecto a b
    return dw, db

# Definir el algoritmo de descenso de gradiente tipo Batch
def descenso_gradiente(w, b, alpha, epochs):
    historial_costo = [] # Lista para guardar los valores de la función de costo en cada iteración
    for i in range(iteraciones):
        dw, db = gradiente(w, b) # Calcular el gradiente
        w = w - alpha * dw # Actualizar el peso
        b = b - alpha * db # Actualizar el sesgo
        c = costo(w, b) # Calcular el costo
        historial_costo.append(c) # Guardar el costo en la lista
        print(f"Iteraciones {i+1}: w = {w:.3f}, b = {b:.3f}, costo = {c:.3f}") # Imprimir los valores en cada iteración
    return w, b, historial_costo

# Ejecutar el algoritmo y obtener los parámetros óptimos y el historial de costo
w_optimo, b_optimo, historial_costo = descenso_gradiente(w, b, alpha, iteraciones)
plt.figure(figsize=(12,6))
# Graficar el historial de costo
plt.plot(historial_costo)
plt.scatter(range(iteraciones),historial_costo, color='red',marker='o',label='Valor de los saltos del descenso MSE')
plt.xlabel("Epoch")
plt.ylabel("Costo")
plt.show()
plt.figure(figsize=(12,6))
# Graficar los datos y la recta ajustada por el modelo
plt.scatter(X, y)
plt.plot(X, w_optimo * X + b_optimo, c="red")
plt.xlabel("X")
plt.ylabel("y")
plt.show()
# Out:
# Iteraciones 1: w = 0.153, b = 0.141, costo = 49.112
# Iteraciones 2: w = 0.299, b = 0.275, costo = 45.235
# Iteraciones 3: w = 0.439, b = 0.405, costo = 41.672
# Iteraciones 4: w = 0.573, b = 0.529, costo = 38.397
# Iteraciones 5: w = 0.702, b = 0.648, costo = 35.386
# Iteraciones 6: w = 0.825, b = 0.763, costo = 32.620
# Iteraciones 7: w = 0.943, b = 0.872, costo = 30.077
# Iteraciones 8: w = 1.056, b = 0.978, costo = 27.739
# Iteraciones 9: w = 1.164, b = 1.079, costo = 25.591
# Iteraciones 10: w = 1.268, b = 1.176, costo = 23.616
# Iteraciones 11: w = 1.367, b = 1.269, costo = 21.802
# Iteraciones 12: w = 1.463, b = 1.358, costo = 20.134
# Iteraciones 13: w = 1.554, b = 1.444, costo = 18.600
# Iteraciones 14: w = 1.641, b = 1.526, costo = 17.191
# Iteraciones 15: w = 1.724, b = 1.605, costo = 15.896
# Iteraciones 16: w = 1.805, b = 1.681, costo = 14.705
# Iteraciones 17: w = 1.881, b = 1.754, costo = 13.611
# Iteraciones 18: w = 1.954, b = 1.824, costo = 12.605
# Iteraciones 19: w = 2.025, b = 1.891, costo = 11.680
# Iteraciones 20: w = 2.092, b = 1.955, costo = 10.830
# Iteraciones 21: w = 2.156, b = 2.017, costo = 10.049
# Iteraciones 22: w = 2.218, b = 2.077, costo = 9.331
# Iteraciones 23: w = 2.277, b = 2.134, costo = 8.671
# Iteraciones 24: w = 2.333, b = 2.189, costo = 8.064
# Iteraciones 25: w = 2.387, b = 2.241, costo = 7.506
# Iteraciones 26: w = 2.439, b = 2.292, costo = 6.994
# Iteraciones 27: w = 2.489, b = 2.341, costo = 6.522
# Iteraciones 28: w = 2.536, b = 2.387, costo = 6.089
# Iteraciones 29: w = 2.581, b = 2.432, costo = 5.691
# Iteraciones 30: w = 2.625, b = 2.475, costo = 5.325
# Iteraciones 31: w = 2.666, b = 2.517, costo = 4.988
# Iteraciones 32: w = 2.706, b = 2.557, costo = 4.679
# Iteraciones 33: w = 2.744, b = 2.595, costo = 4.394
# Iteraciones 34: w = 2.780, b = 2.632, costo = 4.133
# Iteraciones 35: w = 2.815, b = 2.667, costo = 3.892
# Iteraciones 36: w = 2.848, b = 2.701, costo = 3.671
# Iteraciones 37: w = 2.880, b = 2.734, costo = 3.468
# Iteraciones 38: w = 2.910, b = 2.765, costo = 3.281
# Iteraciones 39: w = 2.939, b = 2.795, costo = 3.109
# Iteraciones 40: w = 2.967, b = 2.825, costo = 2.951
# Iteraciones 41: w = 2.993, b = 2.853, costo = 2.805
# Iteraciones 42: w = 3.018, b = 2.879, costo = 2.672
# Iteraciones 43: w = 3.043, b = 2.905, costo = 2.549
# Iteraciones 44: w = 3.066, b = 2.930, costo = 2.435
# Iteraciones 45: w = 3.088, b = 2.954, costo = 2.331
# Iteraciones 46: w = 3.109, b = 2.977, costo = 2.236
# Iteraciones 47: w = 3.129, b = 3.000, costo = 2.148
# Iteraciones 48: w = 3.148, b = 3.021, costo = 2.067
# Iteraciones 49: w = 3.166, b = 3.042, costo = 1.992
# Iteraciones 50: w = 3.184, b = 3.062, costo = 1.924
# Iteraciones 51: w = 3.200, b = 3.081, costo = 1.861
# Iteraciones 52: w = 3.216, b = 3.099, costo = 1.802
# Iteraciones 53: w = 3.232, b = 3.117, costo = 1.749
# Iteraciones 54: w = 3.246, b = 3.134, costo = 1.700
# Iteraciones 55: w = 3.260, b = 3.151, costo = 1.655
# Iteraciones 56: w = 3.273, b = 3.166, costo = 1.613
# Iteraciones 57: w = 3.285, b = 3.182, costo = 1.574
# Iteraciones 58: w = 3.297, b = 3.197, costo = 1.539
# Iteraciones 59: w = 3.309, b = 3.211, costo = 1.506
# Iteraciones 60: w = 3.319, b = 3.225, costo = 1.476
# Iteraciones 61: w = 3.330, b = 3.238, costo = 1.449
# Iteraciones 62: w = 3.339, b = 3.251, costo = 1.423
# Iteraciones 63: w = 3.349, b = 3.263, costo = 1.400
# Iteraciones 64: w = 3.357, b = 3.275, costo = 1.378
# Iteraciones 65: w = 3.366, b = 3.287, costo = 1.358
# Iteraciones 66: w = 3.374, b = 3.298, costo = 1.340
# Iteraciones 67: w = 3.381, b = 3.309, costo = 1.323
# Iteraciones 68: w = 3.388, b = 3.319, costo = 1.307
# Iteraciones 69: w = 3.395, b = 3.329, costo = 1.292
# Iteraciones 70: w = 3.402, b = 3.339, costo = 1.279
# Iteraciones 71: w = 3.408, b = 3.349, costo = 1.266
# Iteraciones 72: w = 3.413, b = 3.358, costo = 1.255
# Iteraciones 73: w = 3.419, b = 3.367, costo = 1.244
# Iteraciones 74: w = 3.424, b = 3.375, costo = 1.235
# Iteraciones 75: w = 3.429, b = 3.384, costo = 1.225
# Iteraciones 76: w = 3.433, b = 3.392, costo = 1.217
# Iteraciones 77: w = 3.438, b = 3.400, costo = 1.209
# Iteraciones 78: w = 3.442, b = 3.407, costo = 1.202
# Iteraciones 79: w = 3.446, b = 3.414, costo = 1.195
# Iteraciones 80: w = 3.449, b = 3.422, costo = 1.189
# Iteraciones 81: w = 3.452, b = 3.429, costo = 1.183
# Iteraciones 82: w = 3.456, b = 3.435, costo = 1.178
# Iteraciones 83: w = 3.459, b = 3.442, costo = 1.173
# Iteraciones 84: w = 3.461, b = 3.448, costo = 1.168
# Iteraciones 85: w = 3.464, b = 3.454, costo = 1.164
# Iteraciones 86: w = 3.466, b = 3.460, costo = 1.160
# Iteraciones 87: w = 3.468, b = 3.466, costo = 1.156
# Iteraciones 88: w = 3.470, b = 3.472, costo = 1.152
# Iteraciones 89: w = 3.472, b = 3.477, costo = 1.149
# Iteraciones 90: w = 3.474, b = 3.483, costo = 1.146
# Iteraciones 91: w = 3.476, b = 3.488, costo = 1.143
# Iteraciones 92: w = 3.477, b = 3.493, costo = 1.140
# Iteraciones 93: w = 3.478, b = 3.498, costo = 1.137
# Iteraciones 94: w = 3.480, b = 3.503, costo = 1.135
# Iteraciones 95: w = 3.481, b = 3.507, costo = 1.133
# Iteraciones 96: w = 3.482, b = 3.512, costo = 1.131
# Iteraciones 97: w = 3.482, b = 3.517, costo = 1.128
# Iteraciones 98: w = 3.483, b = 3.521, costo = 1.127
# Iteraciones 99: w = 3.484, b = 3.525, costo = 1.125
# Iteraciones 100: w = 3.484, b = 3.529, costo = 1.123
