# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/CIFAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Seleccionar algunas imágenes aleatorias del conjunto de prueba
num_images_to_visualize = 5
random_indices = np.random.choice(len(x_test), num_images_to_visualize)

# Hacer predicciones en el conjunto de prueba
predictions = model.predict(x_test)

# Clases predichas y clases reales de las imágenes seleccionadas
predicted_classes = np.argmax(predictions, axis=1)
actual_classes = np.argmax(y_test, axis=1)

# Visualizar imágenes y sus predicciones
plt.figure(figsize=(15, 5))
for i, index in enumerate(random_indices, 1):
    plt.subplot(1, num_images_to_visualize, i)
    plt.imshow(x_test[index])
    plt.title(f'Actual: {actual_classes[index]}, Predicted: {predicted_classes[index]}')
    plt.axis('off')

plt.show()
# Out:
# 313/313 [==============================] - 129s 411ms/step
