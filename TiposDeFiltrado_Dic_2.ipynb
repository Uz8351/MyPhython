# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/TiposDeFiltrado_Dic_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from google.colab import drive
drive.mount('/content/drive')


# Load the image
image = cv2.imread('/content/drive/MyDrive/druida/moni.jpg')

# Define the kernel for the smoothing filter
kernel = np.ones((5, 5), np.float32) / 25

# Apply the smoothing filter
filtered_image = cv2.filter2D(image, -1, kernel)

# Display the original and filtered images
cv2_imshow(image)
cv2_imshow(filtered_image)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=695x584>
# <PIL.Image.Image image mode=RGB size=695x584>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# Crear una imagen de ejemplo
image = np.zeros((100, 100, 3), dtype=np.uint8)
image[:, :50, 0] = 255  # Asignar color azul a la mitad izquierda de la imagen

# Mostrar la imagen usando cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>
