# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/Copia_de_CuadernoEstocas_Aula_48_15_SEP_RV_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Genera datos de ejemplo
np.random.seed(0)
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# Inicialización de parámetros
theta = np.random.randn(2, 1)  # Inicialización aleatoria de los parámetros (intercepto y pendiente)
learning_rate = 0.01
n_iterations = 100
m = len(X)

# Función de costo (error cuadrático medio)
def mse_cost(y_true, y_pred):
    return ((y_true - y_pred) ** 2).mean()

# Historia de costos para trazar
cost_history = []

# Descenso de gradiente estocástico
for iteration in range(n_iterations):
    for i in range(m):
        random_index = np.random.randint(m)  # Elije una muestra aleatoria
        xi = np.vstack([1, X[random_index]])  # Agrega un 1 para el término de intercepto
        yi = y[random_index:random_index+1]
        y_pred = xi.T.dot(theta)
        gradients = -2 * xi.dot(yi - y_pred)
        theta = theta - learning_rate * gradients

    # Calcular el costo después de cada iteración completa
    y_pred = X.dot(theta[1:]) + theta[0]  # Actualizar y_pred
    cost = mse_cost(y, y_pred)
    cost_history.append(cost)

# Trazar la convergencia
plt.figure(figsize=(10, 5))
plt.plot(cost_history)
plt.xlabel('Iteraciones')
plt.ylabel('Error Cuadrático Medio')
plt.title('Convergencia de SGD')
plt.show()
plt.figure(figsize=(10, 5))
plt.scatter(X,y, label='Datos')
x_line = np.array([0, 2])
y_line = theta[0] + theta[1] * x_line
plt.plot(x_line, y_line, c='red', label='Línea ajustada')
plt.xlabel('Eje X')
plt.ylabel('Eje y')
plt.legend()
plt.show()


# Mostrar los parámetros finales
print("Parámetros finales (theta):", theta)
# Out:
# Parámetros finales (theta): [[4.41765603]
#  [2.97255383]]

# %%
import numpy as np
# Genera datos de ejemplo
np.random.seed(0)
X = 2 * np.random.rand(4, 1)
y = 4 + 3 * X + np.random.randn(4, 1)
print("X\n",X)
# Inicialización de parámetros
theta = np.random.randn(2, 1)  # Inicialización aleatoria de los parámetros (intercepto y pendiente)
learning_rate = 0.01
n_iterations = 10
m = len(X)



for i in range(m):#En cada iteración de este bucle, se selecciona una muestra aleatoria del conjunto de datos.
        random_index = np.random.randint(m)  # Elije una muestra aleatoria con valor entre m = len(X)
        xi = np.vstack([1, X[random_index]])  # Agrega un 1 para el término de intercepto
        yi = y[random_index:random_index+1]
        y_pred = xi.T.dot(theta)

        gradients = -2 * xi.dot(yi - y_pred)
        theta = theta - learning_rate * gradients
        print("*****************************")
        print("random_index\n:",random_index)
        print("*****************************")
        print("xi\n:",xi)
        print("*****************************")
        print("yi\n:",yi)
        print("*****************************")
        print("y_pred:\n",y_pred)
        print("*****************************")
        print("gradients:\n",gradients)
        print("*****************************")
        print("theta:\n",theta)
        print("*****************************")
# Out:
# X
#  [[1.09762701]
#  [1.43037873]
#  [1.20552675]
#  [1.08976637]]
# *****************************
# random_index
# : 2
# *****************************
# xi
# : [[1.        ]
#  [1.20552675]]
# *****************************
# yi
# : [[8.56666867]]
# *****************************
# y_pred:
#  [[0.39176863]]
# *****************************
# gradients:
#  [[-16.34980009]
#  [-19.71012141]]
# *****************************
# theta:
#  [[0.06027915]
#  [0.60769972]]
# *****************************
# *****************************
# random_index
# : 3
# *****************************
# xi
# : [[1.        ]
#  [1.08976637]]
# *****************************
# yi
# : [[7.11794189]]
# *****************************
# y_pred:
#  [[0.72252986]]
# *****************************
# gradients:
#  [[-12.79082406]
#  [-13.93900985]]
# *****************************
# theta:
#  [[0.18818739]
#  [0.74708981]]
# *****************************
# *****************************
# random_index
# : 3
# *****************************
# xi
# : [[1.        ]
#  [1.08976637]]
# *****************************
# yi
# : [[7.11794189]]
# *****************************
# y_pred:
#  [[1.00234074]]
# *****************************
# gradients:
#  [[-12.2312023 ]
#  [-13.32915288]]
# *****************************
# theta:
#  [[0.31049941]
#  [0.88038134]]
# *****************************
# *****************************
# random_index
# : 2
# *****************************
# xi
# : [[1.        ]
#  [1.20552675]]
# *****************************
# yi
# : [[8.56666867]]
# *****************************
# y_pred:
#  [[1.37182267]]
# *****************************
# gradients:
#  [[-14.389692  ]
#  [-17.34715866]]
# *****************************
# theta:
#  [[0.45439633]
#  [1.05385293]]
# *****************************
