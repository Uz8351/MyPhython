# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/ClaseAulaB128LunesSep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
np.random.seed(0)
Aleatorios_X = 2 * np.random.rand(150, 1)
Aleatorios_y = 4 + 3 * Aleatorios_X + np.random.randn(150, 1)

# Inicialización de parámetros (pendiente y ordenada al origen)
Pendiente = 0
Intercepto = 0

# Hiperparámetros
Tasa_Aprendizaje = 0.01
Epocas = 100

# Listas para almacenar los valores de pérdida y parámetros en cada época
Perdidas = []
Pendientes = []
Interceptos = []

# Bucle de iteración
for epoch in range(Epocas):
    # Cálculo de las predicciones
    Predicciones = Pendiente * Aleatorios_X + Intercepto

    # Cálculo del error
    Error = y - Predicciones

    # Cálculo de los gradientes
    Gradiente_Pendiente = (-2 / len(Aleatorios_X)) * np.sum(Aleatorios_X * Error)
    Gradiente_Intercepto = (-2 / len(Aleatorios_X)) * np.sum(Error)

    # Actualización de parámetros
    Pendiente -= Tasa_Aprendizaje * Gradiente_Pendiente
    Intercepto -= Tasa_Aprendizaje * Gradiente_Intercepto

    # Cálculo de la función de pérdida (Error cuadrático medio)
    Perdida = np.mean(Error ** 2)

    # Almacenar valores para graficar
    Perdidas.append(Perdida)
    Pendientes.append(Pendiente)
    Interceptos.append(Intercepto)

# Parámetros finales
Final_Pendiente = Pendientes[-1] if Pendientes else 0
Final_Intercepto = Interceptos[-1] if Interceptos else 0

# Gráfica de la pérdida en función de las épocas
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, Epocas + 1), Perdidas, marker='o')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.title('Pérdida en función de las Épocas')

# Gráfica de la regresión lineal ajustada
plt.subplot(1, 2, 2)
plt.scatter(Aleatorios_X, Aleatorios_y, label='Datos reales')
plt.plot(X, Final_Pendiente * Aleatorios_X + Final_Intercepto, color='red', label='Regresión lineal ajustada')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.title('Regresión Lineal Ajustada')

plt.tight_layout()
plt.show()

# Parámetros finales
print(f"Pendiente final: {Final_Pendiente:.4f}")
print(f"Ordenada al origen final: {Final_Intercepto:.4f}")
# Out:
# Pendiente final: 3.4501
# Ordenada al origen final: 3.2805
