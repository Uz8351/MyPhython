# %% [markdown]
# <a href="https://colab.research.google.com/github/Uz8351/MyPhython/blob/master/continuacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input, decode_predictions
import numpy as np

# Cargar el modelo DenseNet121 preentrenado en el conjunto de datos "Flower Recognition"
model = DenseNet121(weights='imagenet')

# Cargar y preprocesar la imagen de la flor de prueba
img_path = '/content/drive/MyDrive/druida/flores/flores1/image_00001.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

# Obtener las predicciones
predictions = model.predict(img_array)

# Decodificar y mostrar las predicciones
decoded_predictions = decode_predictions(predictions, top=3)[0]
for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
    print(f"{i + 1}: {label} ({score:.2f})")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-1ac3c92ee869> in <cell line: 4>()
#       2 drive.mount('/content/drive')
#       3
# ----> 4 import tensorflow as tf
#       5 from tensorflow.keras.preprocessing import image
#       6 from tensorflow.keras.applications.densenet import DenseNet121
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/__init__.py in <module>
#      50 from ._api.v2 import autograph
#      51 from ._api.v2 import bitwise
# ---> 52 from ._api.v2 import compat
#      53 from ._api.v2 import config
#      54 from ._api.v2 import data
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/_api/v2/compat/__init__.py in <module>
#      35 import sys as _sys
#      36
# ---> 37 from . import v1
# ...
